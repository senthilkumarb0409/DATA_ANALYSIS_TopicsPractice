# %%
pwd
# Out:
# 'C:\\sql\\pythonclass\\jupyterpyfiles\\EDA'

# %%
import pandas as pd

# %%
import pandas as pd

heart_df = pd.read_csv(
    "heart.csv",
    skiprows=[0],
    names=[
        "Age", "Sex", "Chest Pain", "Blood Pressure", "Cholesterol",
        "Diabetes", "ECG Result", "Max Heart Rate", "Angina",
        "ST Depression", "ST Slope", "# Major Vessels Coloured",
        "Thal", "Diagnosis"
    ]
)

# %%
heart_df
# Out:
#      Age  Sex  Chest Pain  Blood Pressure  Cholesterol  Diabetes  ECG Result  \
# 0     67    1           1             103          190         0           0
# 1     57    1           2             166          275         0           1
# 2     43    1           3             153          274         0           1
# 3     71    0           0             120          229         1           2
# 4     36    1           0              95          261         0           1
# ..   ...  ...         ...             ...          ...       ...         ...
# 295   63    1           1             122          288         1           1
# 296   53    0           1             144          233         1           0
# 297   57    1           2             138          246         0           2
# 298   46    1           3             122          255         1           0
# 299   74    1           0             153          142         1           2
#
# ...

# %%
heart_df.shape
# Out:
# (300, 14)

# %%
heart_df.columns
# Out:
# Index(['Age', 'Sex', 'Chest Pain', 'Blood Pressure', 'Cholesterol', 'Diabetes',
#        'ECG Result', 'Max Heart Rate', 'Angina', 'ST Depression', 'ST Slope',
#        '# Major Vessels Coloured', 'Thal', 'Diagnosis'],
#       dtype='object')

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       300 non-null    int64
#  1   Sex                       300 non-null    int64
#  2   Chest Pain                300 non-null    int64
#  3   Blood Pressure            300 non-null    int64
#  4   Cholesterol               300 non-null    int64
#  5   Diabetes                  300 non-null    int64
#  6   ECG Result                300 non-null    int64
#  7   Max Heart Rate            300 non-null    int64
#  8   Angina                    300 non-null    int64
#  9   ST Depression             300 non-null    float64
#  10  ST Slope                  300 non-null    int64
#  11  # Major Vessels Coloured  300 non-null    int64
#  12  Thal                      300 non-null    int64
#  13  Diagnosis                 300 non-null    int64
# ...

# %%
heart_df[['Age', 'Cholesterol', 'Blood Pressure']] = heart_df[['Age', 'Cholesterol', 'Blood Pressure']].astype('double')

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       300 non-null    float64
#  1   Sex                       300 non-null    int64
#  2   Chest Pain                300 non-null    int64
#  3   Blood Pressure            300 non-null    float64
#  4   Cholesterol               300 non-null    float64
#  5   Diabetes                  300 non-null    int64
#  6   ECG Result                300 non-null    int64
#  7   Max Heart Rate            300 non-null    int64
#  8   Angina                    300 non-null    int64
#  9   ST Depression             300 non-null    float64
#  10  ST Slope                  300 non-null    int64
#  11  # Major Vessels Coloured  300 non-null    int64
#  12  Thal                      300 non-null    int64
#  13  Diagnosis                 300 non-null    int64
# ...

# %%
# Working with a single variable
# Let us find out the mean age

heart_df['Age'].mean(axis=0)
# Out:
# np.float64(52.32666666666667)

# %%
var_age=heart_df['Age'].var(axis=0)
sd_age=heart_df['Age'].std(axis=0)
print("Variance:", var_age)
print("Standard Deviation:", sd_age)
# Out:
# Variance: 192.86283166109254
# Standard Deviation: 13.88750631542944

# %%
heart_df['Age'].describe()
# Out:
# count    300.000000
# mean      52.326667
# std       13.887506
# min       29.000000
# 25%       40.000000
# 50%       53.000000
# 75%       64.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
age_itr=(76-29)
print("The interqualrtile range for age is:", age_itr)
# Out:
# The interqualrtile range for age is: 47

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
from pylab import hist, show, xticks, yticks

# Create the figure and axes
fig, ax = plt.subplots(figsize=(10, 7))

# Plot histogram of Age
ax.hist(heart_df['Age'], bins=[20, 30, 40, 50, 60, 70, 80], color='plum', edgecolor='black')

# Set x and y ticks
xticks(range(20, 90, 10))
yticks(range(0, 150, 25))

# Labels and formatting
plt.xlabel("Age", fontsize=20)
plt.ylabel("No. of occurrences", fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)

# Show the plot
plt.show()

# %%
from pylab import *

fig = figure(figsize=(10, 10))           # Create a figure object with size 10x10 inches
ax = fig.add_subplot(111)                # Add a subplot (1 row, 1 column, 1st plot)

ax.boxplot(heart_df['Age'])              # Create a boxplot for the 'Age' column
ax.set_ylabel('Age', fontsize=20)        # Set the y-axis label
ax.axes.xaxis.set_visible(False)         # Hide the x-axis (since it's just one boxplot)
ax.tick_params(axis='both', which='major', labelsize=18)  # Make tick labels larger

plt.show()                               # Display the plot

# %%
heart_df[['Age','Blood Pressure','Cholesterol','Max Heart Rate']].describe()
# Out:
#               Age  Blood Pressure  Cholesterol  Max Heart Rate
# count  300.000000      300.000000   300.000000      300.000000
# mean    52.326667      128.660000   248.590000      151.060000
# std     13.887506       20.674845    48.056216       22.173904
# min     29.000000       76.000000   123.000000       86.000000
# 25%     40.000000      114.000000   216.000000      136.000000
# 50%     53.000000      128.000000   251.000000      150.000000
# 75%     64.000000      143.000000   278.250000      166.000000
# max     76.000000      191.000000   376.000000      207.000000

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.histplot(data=heart_df, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=heart_df, x='Blood Pressure')
# Out:
# <Axes: xlabel='Blood Pressure', ylabel='Count'>

# %%
sns.histplot(data=heart_df, x='Cholesterol')
# Out:
# <Axes: xlabel='Cholesterol', ylabel='Count'>

# %%
sns.histplot(data=heart_df, x='Max Heart Rate')
# Out:
# <Axes: xlabel='Max Heart Rate', ylabel='Count'>

# %%
sns.boxplot(data=heart_df, y='Age')
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(data=heart_df, y='Blood Pressure')
# Out:
# <Axes: ylabel='Blood Pressure'>

# %%
sns.boxplot(data=heart_df, y='Cholesterol')
# Out:
# <Axes: ylabel='Cholesterol'>

# %%
sns.boxplot(data=heart_df, y='Max Heart Rate')
# Out:
# <Axes: ylabel='Max Heart Rate'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
ax = sns.countplot(data=heart_df, x='Diagnosis', palette='pastel')
ax.set_xticklabels(["Normal", "Diseased"])
ax.set_xlabel("Diagnosis", fontsize=14)
ax.set_ylabel("Count", fontsize=14)
plt.tick_params(axis='both', labelsize=12)
plt.title("Diagnosis Count", fontsize=16)

# for p in ax.patches:
#     height = p.get_height()
#     ax.annotate(f'{height}', 
#                 (p.get_x() + p.get_width() / 2, height), 
#                 ha='center', va='bottom', fontsize=12)

plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\194933752.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=heart_df, x='Diagnosis', palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\194933752.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Normal", "Diseased"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
ax = sns.countplot(data=heart_df, x='Sex', palette='Set2')
ax.set_xticklabels(["Female", "Male"])
ax.set_xlabel("Sex", fontsize=14)
ax.set_ylabel("Count", fontsize=14)
plt.title("Gender Distribution", fontsize=16)
plt.tick_params(axis='both', labelsize=12)

# # Show count labels on top of bars
# for p in ax.patches:
#     height = p.get_height()
#     ax.annotate(f'{height}', 
#                 (p.get_x() + p.get_width() / 2, height), 
#                 ha='center', va='bottom', fontsize=12)

plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\810478813.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=heart_df, x='Sex', palette='Set2')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\810478813.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Female", "Male"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
ax = sns.boxplot(data=heart_df, y='Blood Pressure', x='Diagnosis', palette='pastel')
ax.set_xticklabels(["Normal", "Diseased"])
ax.set_xlabel("Diagnosis", fontsize=14)
ax.set_ylabel("Blood Pressure", fontsize=14)
plt.title("Blood Pressure by Diagnosis", fontsize=16)
plt.tick_params(axis='both', labelsize=12)
plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\4104478729.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=heart_df, y='Blood Pressure', x='Diagnosis', palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\4104478729.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Normal", "Diseased"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
ax = sns.boxplot(data=heart_df, y='Blood Pressure', x='Diagnosis', showmeans=True, palette='pastel')
ax.set_xticklabels(["Normal", "Diseased"])
ax.set_xlabel("Diagnosis", fontsize=14)
ax.set_ylabel("Blood Pressure", fontsize=14)
plt.title("Blood Pressure by Diagnosis (with Mean)", fontsize=16)
plt.tick_params(axis='both', labelsize=12)
plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\81711484.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=heart_df, y='Blood Pressure', x='Diagnosis', showmeans=True, palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\81711484.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Normal", "Diseased"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
ax = sns.barplot(data=heart_df, y='Blood Pressure', x='Diagnosis', ci='sd', capsize=0.1, palette='pastel')
ax.set_xticklabels(["Normal", "Diseased"])
ax.set_xlabel("Diagnosis", fontsize=14)
ax.set_ylabel("Mean Blood Pressure", fontsize=14)
plt.title("Mean Blood Pressure by Diagnosis (with SD error bars)", fontsize=16)
plt.tick_params(axis='both', labelsize=12)
plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\3853739698.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.barplot(data=heart_df, y='Blood Pressure', x='Diagnosis', ci='sd', capsize=0.1, palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\3853739698.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=heart_df, y='Blood Pressure', x='Diagnosis', ci='sd', capsize=0.1, palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\3853739698.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Normal", "Diseased"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
ax = sns.boxplot(data=heart_df, y='Age', x='Diagnosis', palette='pastel')
ax.set_xticklabels(["Normal", "Diseased"])
ax.set_xlabel("Diagnosis", fontsize=14)
ax.set_ylabel("Age", fontsize=14)
plt.title("Age Distribution by Diagnosis", fontsize=16)
plt.tick_params(axis='both', labelsize=12)
plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\1112155626.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=heart_df, y='Age', x='Diagnosis', palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\1112155626.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Normal", "Diseased"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
ax = sns.barplot(data=heart_df, y='Age', x='Diagnosis', ci='sd', capsize=0.1, palette='pastel')
ax.set_xticklabels(["Normal", "Diseased"])
ax.set_xlabel("Diagnosis", fontsize=14)
ax.set_ylabel("Mean Age", fontsize=14)
plt.title("Mean Age by Diagnosis (with SD Error Bars)", fontsize=16)
plt.tick_params(axis='both', labelsize=12)
plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\345701715.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.barplot(data=heart_df, y='Age', x='Diagnosis', ci='sd', capsize=0.1, palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\345701715.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=heart_df, y='Age', x='Diagnosis', ci='sd', capsize=0.1, palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\345701715.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Normal", "Diseased"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
ax = sns.boxplot(data=heart_df, y='Blood Pressure', x='ECG Result', palette='pastel')
ax.set_xticklabels(["Normal", "Intermediate", "Severe"])
ax.set_xlabel("ECG Result", fontsize=14)
ax.set_ylabel("Blood Pressure", fontsize=14)
plt.title("Blood Pressure by ECG Result", fontsize=16)
plt.tick_params(axis='both', labelsize=12)
plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\3399308352.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=heart_df, y='Blood Pressure', x='ECG Result', palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\3399308352.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Normal", "Intermediate", "Severe"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
ax = sns.barplot(data=heart_df, y='Blood Pressure', x='ECG Result', ci='sd', capsize=0.1, palette='pastel')
ax.set_xticklabels(["Normal", "Intermediate", "Severe"])
ax.set_xlabel("ECG Result", fontsize=14)
ax.set_ylabel("Mean Blood Pressure", fontsize=14)
plt.title("Mean Blood Pressure by ECG Result (with SD error bars)", fontsize=16)
plt.tick_params(axis='both', labelsize=12)
plt.show()
# Out:
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\1763636209.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.barplot(data=heart_df, y='Blood Pressure', x='ECG Result', ci='sd', capsize=0.1, palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\1763636209.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=heart_df, y='Blood Pressure', x='ECG Result', ci='sd', capsize=0.1, palette='pastel')
# C:\Users\Senthil Kumar\AppData\Local\Temp\ipykernel_21448\1763636209.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Normal", "Intermediate", "Severe"])

# %%
plt.scatter(heart_df['Age'], heart_df['Blood Pressure'])
plt.xlabel("Age", fontsize=12)
plt.ylabel("Blood Pressure (in mmHG)", fontsize=12)
# Out:
# Text(0, 0.5, 'Blood Pressure (in mmHG)')

# %%
plt.scatter(heart_df['Cholesterol'], heart_df['Blood Pressure'])
plt.xlabel("Cholesterol (in mg/dL)", fontsize=12)
plt.ylabel("Blood Pressure (in mmHg)", fontsize=12)
# Out:
# Text(0, 0.5, 'Blood Pressure (in mmHg)')

# %%
plt.scatter(heart_df['Blood Pressure'], heart_df['Max Heart Rate'])
plt.ylabel("Max Heart Rate", fontsize=12)
plt.xlabel("Blood Pressure (in mmHg)", fontsize=12)
# Out:
# Text(0.5, 0, 'Blood Pressure (in mmHg)')

# %%
plt.scatter(heart_df['Age'], heart_df['Max Heart Rate'])
plt.xlabel("Age", fontsize=12)
plt.ylabel("Max Heart Rate", fontsize=12)
# Out:
# Text(0, 0.5, 'Max Heart Rate')

# %%
heart_df[['Age',"Blood Pressure","Cholesterol","Max Heart Rate"]].corr()
# Out:
#                      Age  Blood Pressure  Cholesterol  Max Heart Rate
# Age             1.000000       -0.049886    -0.040280       -0.030366
# Blood Pressure -0.049886        1.000000    -0.007129        0.041424
# Cholesterol    -0.040280       -0.007129     1.000000       -0.018702
# Max Heart Rate -0.030366        0.041424    -0.018702        1.000000

# %%
import numpy as np

# Linear regression: fit a line (y = m*x + b)
Slope, Intercept = np.polyfit(heart_df['Age'], heart_df['Blood Pressure'], 1)

print("Slope:", Slope)
print("Intercept:", Intercept)
# Out:
# Slope: -0.07426700291725734
# Intercept: 132.5461447059837

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

# Scatter plot of actual data
plt.plot(heart_df['Age'], heart_df['Blood Pressure'], 'o', label='Data')

# Plotting the linear regression line
plt.plot(heart_df['Age'], Slope * heart_df['Age'] + Intercept, color='red', label='Fit Line')

# Axis labels
plt.xlabel("Age", fontsize=15)
plt.ylabel("Blood Pressure", fontsize=15)

# Optional: add legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fit linear regression: Blood Pressure ~ Cholesterol
Slope1, Intercept1 = np.polyfit(heart_df['Cholesterol'], heart_df['Blood Pressure'], 1)

print("Slope:", Slope1)
print("Intercept:", Intercept1)

# Plot data points
plt.figure(figsize=(8, 5))
plt.plot(heart_df['Cholesterol'], heart_df['Blood Pressure'], 'o', label='Data')

# Plot regression line
plt.plot(heart_df['Cholesterol'], Slope1 * heart_df['Cholesterol'] + Intercept1, color='red', label='Fit Line')

plt.xlabel("Cholesterol", fontsize=15)
plt.ylabel("Blood Pressure", fontsize=15)
plt.title("Linear Fit: Cholesterol vs Blood Pressure")
plt.legend()
plt.show()
# Out:
# Slope: -0.0030670348753677225
# Intercept: 129.42243419966763

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fit linear regression: Blood Pressure ~ Age
Slope2, Intercept2 = np.polyfit(heart_df['Age'], heart_df['Blood Pressure'], 1)  # 1 denotes linear fit (Age^1)

print("Slope:", Slope2)
print("Intercept:", Intercept2)

# Plot data points
plt.figure(figsize=(8, 5))
plt.plot(heart_df['Age'], heart_df['Blood Pressure'], 'o', label='Data')

# Plot regression line
plt.plot(heart_df['Age'], Slope2 * heart_df['Age'] + Intercept2, color='red', label='Fit Line')

plt.xlabel("Age", fontsize=15)
plt.ylabel("Blood Pressure", fontsize=15)
plt.title("Linear Fit: Age vs Blood Pressure")
plt.legend()
plt.show()
# Out:
# Slope: -0.07426700291725734
# Intercept: 132.5461447059837

# %%
import numpy as np
import matplotlib.pyplot as plt

# Linear regression: Max Heart Rate ~ Age
Slope3, Intercept3 = np.polyfit(heart_df['Age'], heart_df['Max Heart Rate'], 1)  # 1 = linear fit

print("Slope:", Slope3)
print("Intercept:", Intercept3)

# Plot data points
plt.figure(figsize=(8, 5))
plt.plot(heart_df['Age'], heart_df['Max Heart Rate'], 'o', label='Data')

# Plot regression line using Slope3 and Intercept3
plt.plot(heart_df['Age'], Slope3 * heart_df['Age'] + Intercept3, color='red', label='Fit Line')

plt.xlabel("Age", fontsize=15)
plt.ylabel("Max Heart Rate", fontsize=15)
plt.title("Linear Fit: Age vs Max Heart Rate")
plt.legend()
plt.show()
# Out:
# Slope: -0.04848403992740661
# Intercept: 153.59700819593473

# %%
import seaborn as sns

sns.pairplot(heart_df[['Age', 'Blood Pressure', 'Cholesterol', 'Max Heart Rate']])
